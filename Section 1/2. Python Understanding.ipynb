# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print("Hello World")
# Out:
# Hello World

# %%
name = "Atif"
age = 15
height = 5.1
is_gamer = True

print(name , age , height , is_gamer)
# Out:
# Atif 15 5.1 True

# %%
user_name = input("Enter Your Name : ")
print("Your Name is  : " , user_name)
# Out:
# Your Name is  :  Atif

# %%
x = 3 
y = 4 
print(x+y )
print(x-y )
print(x*y )
print(x/y )
print(x//y )
print(x**y )
# Out:
# 7
# -1
# 12
# 0.75
# 0
# 81

# %%
age = int(input("Enter Your Age : " ))
if age>18 :
    print("You are an Adult")
elif age >13 :
    print("you Are Teenager")
else:
    print("You Are Not Adult")
# Out:
# you Are Teenager

# %%
count = 0
while count < 5:
    print("Count is : " , count)
    count = count+1
# Out:
# Count is :  0
# Count is :  1
# Count is :  2
# Count is :  3
# Count is :  4

# %%
marks = [11 , 333  ,2   , 33 , 44 , 22 , 99]
for i in marks:
    print(i)
# Out:
# 11
# 333
# 2
# 33
# 44
# 22
# 99

# %%
marks[0]
# Out:
# 11

# %%
marks[3]
# Out:
# 33

# %%
marks[3] = 44
marks[3]
# Out:
# 44

# %%
def say_hello(i):

    print(f"Grapes {i} are everything in this world just keep this in your mind")

say_hello("Nice")
# Out:
# Grapes Nice are everything in this world just keep this in your mind

# %%
def multiply(a , b):
    return a*b

multiply( 2 , 4 )
# Out:
# 8

# %%
import random 
secret_number = random.randint(1 , 10 )
attempts = 3 

print("I M Thinking of a number 1 & 10 ")

while attempts > 0:
    guess = int(input ("Take a guess : "))

    if guess== secret_number:
        print("Congratulation")
        break
    elif guess < secret_number:
        print("Too Low ")
    else:
        print("Too High")
    
    attempts -= 1 


if attempts == 0 :
    print("Sorry , you have run out of guess tries.")
# Out:
# I M Thinking of a number 1 & 10
# Too Low
# Too Low
# Too Low
# Sorry , you have run out of guess tries.
